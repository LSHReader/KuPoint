# %% [markdown]
# # Data Exploration

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import os

# %%
#데이터가져오기
Product = pd.read_csv("C:/Users/lsh93/Desktop/data/Product.csv")
Search1 = pd.read_csv("C:/Users/lsh93/Desktop/data/Search1.csv")
Search2 = pd.read_csv("C:/Users/lsh93/Desktop/data/Search2.csv")
Custom = pd.read_csv("C:/Users/lsh93/Desktop/data/Custom.csv")
Session = pd.read_csv("C:/Users/lsh93/Desktop/data/Session.csv")
Master = pd.read_csv("C:/Users/lsh93/Desktop/data/Master.csv")

# %% [raw]
# Merge following csv files
#
# Product.csv : CLNT_ID, SESS_ID(Brdige), PD_C(Bridge), PD_BUY_CT, PD_BUY_AM
# Master.csv : PD_C(Bridge), CLAC1_NM, CLAC2_NM, CLAC3_NM
# Session.csv : SESS_ID(Bridge), SESS_DT, DVC_CTG_NM, ZON_NM, CITY_NM
# Custom.csv : CLNT_ID, CLNT_GENDER, CLNT_AGE
# To get data below
# Client Information
#
# CLNT_ID : Client ID (Primary Key)
# CLNT_GENDER : Client Gender
# CLNT_AGE : Client Age
# DVC_CTG_NM : Client Device
# ZON_NM : Client Location (briefly)
# CITY_NM : Client Location (in detail)
# Purchase Information
#
# SESS_DT : Session Date
# PD_BUY_CT : Number of product purchased
# PD_BUY_AM : Price of product purchased
# Product Information
#
# CLAC1_NM : Product group (largest)(대분류)
# CLAC2_NM : Product group (moderate)(중분류)
# CLAC3_NM : Product group (smallest)(소분류)

# %% [markdown]
# # 1. Custom_Product_Master
# # 성별 기준으로 구매한 상품 브랜드의 트렌드

# %%
#Data Inner Join
Product_Master = pd.merge(Product,Master)

# %%
Product_Master.head()
# Out:
#    CLNT_ID  SESS_ID  HITS_SEQ    PD_C     PD_ADD_NM PD_BRA_NM PD_BUY_AM  \
# 0  4139680  7605037        12  642112       색상:워터멜론   [바비브라운]    39,000
# 1  4350334  2023661        77  642112    색상:엔젤 / 1개     바비브라운    39,000
# 2  5172356  4714565        47  642112        색상:카바나   [바비브라운]    39,000
# 3  5444959  6843465        24  642112  색상:워터멜론 / 1개     바비브라운    39,000
# 4  5461276  7896792        53  642112  색상:워터멜론 / 1개     바비브라운    39,000
#
#   PD_BUY_CT          PD_NM  CLAC1_NM CLAC2_NM       CLAC3_NM
# 0         1  크러쉬드 립칼라 - 플럼  화장품/뷰티케어     메이크업  블러셔/쉐이딩/하이라이터
# 1         1  크러쉬드 립칼라 - 플럼  화장품/뷰티케어     메이크업  블러셔/쉐이딩/하이라이터
# 2         1  크러쉬드 립칼라 - 플럼  화장품/뷰티케어     메이크업  블러셔/쉐이딩/하이라이터
# 3         1  크러쉬드 립칼라 - 플럼  화장품/뷰티케어     메이크업  블러셔/쉐이딩/하이라이터
# 4         1  크러쉬드 립칼라 - 플럼  화장품/뷰티케어     메이크업  블러셔/쉐이딩/하이라이터

# %%
Custom_Product_Master = pd.merge(Custom, Product_Master)

# %%
Custom_Product_Master.head()
# Out:
#    CLNT_ID CLNT_GENDER  CLNT_AGE  SESS_ID  HITS_SEQ    PD_C  \
# 0  4830726           F        30  2546785        45  357970
# 1  4830726           F        30  2546785        27  357970
# 2  4830874           F        40  1456881        35   81976
# 3  4830874           F        40  1456881        35   81976
# 4  4830874           F        40  1456881        35   81976
#
#                        PD_ADD_NM   PD_BRA_NM PD_BUY_AM PD_BUY_CT  \
# 0                             1개  에스까다(선글라스)   130,000         1
# 1                             1개  에스까다(선글라스)   130,000         1
# 2   색상:버건디(90)|사이즈:S(90/66) / 1개          유닛    69,000         1
# 3  색상:아이보리(41)|사이즈:S(90/66) / 1개          유닛    69,000         1
# 4  색상:D/그린(04)|사이즈:S(90/66) / 1개          유닛    69,000         1
#
#                                                PD_NM CLAC1_NM CLAC2_NM  \
# 0                                SES937G 531X SES937     패션잡화  안경/선글라스
# ...

# %%
#데이터 병합하기 
Custom_Product_Master = pd.merge(Custom,Product_Master)

# %%
Custom_Product_Master[100:]
# Out:
#          CLNT_ID CLNT_GENDER  CLNT_AGE   SESS_ID  HITS_SEQ    PD_C  \
# 100      4839353           F        30   5814936        27  512300
# 101      4839353           F        30   3341607        14  507156
# 102      4839427           F        30   6874315        35    1955
# 103      4839427           F        30   9222022        30  583553
# 104      4839489           F        40   2842534       121   66329
# 105      4839489           F        40   2842534       121  686712
# 106      4839489           F        40   2842534       121  639675
# 107      4839742           F        30  10461815        28  658169
# 108      4839742           F        30  10265791        29    1801
# 109      4839795           F        40    849458        64  764067
# 110      4839795           F        40    849458        64  764157
# 111      4839795           F        40    849458        64  764068
# 112      4839826           F        40   9554146       353  536187
# ...

# %%
#Femaie
Custom_Product_Master['CLNT_GENDER'] == 'F'
# Out:
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
# 5           True
# 6           True
# 7           True
# 8           True
# 9           True
# 10          True
# 11          True
# 12          True
# 13          True
# 14          True
# 15          True
# 16          True
# 17          True
# 18          True
# 19          True
# 20          True
# 21          True
# 22          True
# 23          True
# 24          True
# 25          True
# 26          True
# 27          True
# 28          True
# 29          True
#            ...
# 3988557     True
# 3988558     True
# 3988559     True
# 3988560     True
# 3988561     True
# 3988562     True
# 3988563     True
# 3988564     True
# 3988565     True
# 3988566     True
# 3988567     True
# 3988568     True
# 3988569     True
# 3988570     True
# 3988571     True
# 3988572     True
# 3988573    False
# 3988574    False
# 3988575     True
# 3988576     True
# 3988577     True
# ...

# %%
Custom_Product_Master.shape
# Out:
# (3988587, 14)

# %%
CPM_F = Custom_Product_Master[Custom_Product_Master['CLNT_GENDER'] == 'F']
CPM_F.shape
# Out:
# (3491522, 14)

# %%
CPM_F = CPM_F[['CLAC1_NM']]

# %%
CPM_F.head()
# Out:
#   CLAC1_NM
# 0     패션잡화
# 1     패션잡화
# 2     여성의류
# 3     여성의류
# 4     여성의류

# %%
CPM_F.iloc[:, 0].value_counts()
# Out:
# 여성의류          520796
# 화장품/뷰티케어      424984
# 스포츠패션         355186
# 패션잡화          333476
# 남성의류          311051
# 속옷/양말/홈웨어     297714
# 유아동의류         261288
# 출산/육아용품       109535
# 시즌스포츠         109186
# 퍼스널케어          94668
# 건강식품           81084
# 원예/애완          67074
# 침구/수예          55428
# 식기/조리기구        54500
# 완구             38669
# 주방잡화           34232
# 문구/사무용품        33230
# 음료             32971
# 세제/위생          30697
# 청소/세탁/욕실용품     30535
# 가구             28424
# 생활/주방가전        27900
# 아웃도어/레저        26200
# 구기/필드스포츠       19469
# 헬스/피트니스        18668
# 모바일            15727
# 과일             15003
# 컴퓨터            10520
# 냉장식품            9282
# 계절가전            8962
# 냉동식품            8678
# 상품권             8064
# 축산물             6129
# 인테리어/조명         5025
# 냉장/세탁가전         3864
# 영상/음향가전         2749
# 자동차용품            554
# Name: CLAC1_NM, dtype: int64

# %%
#Female(여성)의 상품 대분류 별 구매
for column_idx in range(1) :
    print('\n* ', CPM_F.dtypes.index[column_idx])
    CPM_F.iloc[:, column_idx].value_counts().plot.bar()
    plt.show()
# Out:
# *  CLAC1_NM

# %%
#Male
CPM_M = Custom_Product_Master[Custom_Product_Master['CLNT_GENDER'] == 'M']
CPM_M = CPM_M[['CLAC1_NM']]

# %%
CPM_M.iloc[:, 0].value_counts()
# Out:
# 남성의류          100356
# 스포츠패션          88931
# 패션잡화           38844
# 화장품/뷰티케어       36702
# 속옷/양말/홈웨어      33375
# 여성의류           26710
# 유아동의류          21355
# 건강식품           14110
# 시즌스포츠          13292
# 출산/육아용품        11419
# 퍼스널케어          10876
# 아웃도어/레저         8778
# 원예/애완           7987
# 완구              6689
# 구기/필드스포츠        6244
# 음료              6009
# 침구/수예           5805
# 식기/조리기구         5589
# 가구              5566
# 문구/사무용품         5334
# 생활/주방가전         5057
# 모바일             4897
# 컴퓨터             4510
# 청소/세탁/욕실용품      4314
# 세제/위생           4301
# 주방잡화            3820
# 과일              2789
# 상품권             2260
# 계절가전            1833
# 헬스/피트니스         1823
# 냉장식품            1524
# 냉동식품            1504
# 축산물             1446
# 영상/음향가전         1038
# 냉장/세탁가전          970
# 인테리어/조명          583
# 자동차용품            425
# Name: CLAC1_NM, dtype: int64

# %%
#Male(남성)의 상품 대분류 별 구매
for column_idx in range(1) :
    print('\n* ', CPM_M.dtypes.index[column_idx])
    CPM_M.iloc[:, column_idx].value_counts().plot.bar()
    plt.show()
# Out:
# *  CLAC1_NM

# %% [markdown]
# # 연령대 별로 구매한 상품 대분류 트렌드

# %%
CPM_AGE = Custom_Product_Master[['CLNT_AGE','CLAC1_NM']]

# %%
CPM_AGE.head()
# Out:
#    CLNT_AGE CLAC1_NM
# 0        30     패션잡화
# 1        30     패션잡화
# 2        40     여성의류
# 3        40     여성의류
# 4        40     여성의류

# %%
CPM_AGE['CLNT_AGE'].value_counts()
# Out:
# 30    1751416
# 40    1574966
# 20     354299
# 50     252729
# 60      37308
# 10      12143
# 70       5471
# 80        255
# Name: CLNT_AGE, dtype: int64

# %%
print('\n*', 'Age:', 10, '대')
CPM_AGE_temp = CPM_AGE[CPM_AGE['CLNT_AGE'] == 10]
CPM_AGE_temp.iloc[:, 1].value_counts()
# Out:
# * Age: 10 대
# 스포츠패션         3346
# 화장품/뷰티케어      3033
# 패션잡화          1554
# 남성의류           939
# 속옷/양말/홈웨어      629
# 여성의류           486
# 시즌스포츠          252
# 퍼스널케어          239
# 모바일            212
# 상품권            174
# 건강식품           173
# 원예/애완          145
# 출산/육아용품        116
# 음료              92
# 유아동의류           91
# 문구/사무용품         88
# 구기/필드스포츠        79
# 아웃도어/레저         73
# 식기/조리기구         57
# 완구              51
# 컴퓨터             49
# 헬스/피트니스         31
# 침구/수예           31
# 축산물             30
# 세제/위생           30
# 청소/세탁/욕실용품      29
# 생활/주방가전         20
# 가구              20
# 냉동식품            15
# 계절가전            14
# 냉장식품            13
# 과일              11
# 주방잡화             8
# 영상/음향가전          6
# 인테리어/조명          5
# 냉장/세탁가전          2
# Name: CLAC1_NM, dtype: int64

# %%
print('\n*', 'Age:', 20, '대')
CPM_AGE_temp = CPM_AGE[CPM_AGE['CLNT_AGE'] == 20]
CPM_AGE_temp.iloc[:, 1].value_counts()
# Out:
# * Age: 20 대
# 화장품/뷰티케어      86995
# 스포츠패션         43197
# 패션잡화          36763
# 여성의류          34163
# 남성의류          33253
# 속옷/양말/홈웨어     26436
# 퍼스널케어         10942
# 원예/애완         10103
# 시즌스포츠          8229
# 건강식품           8144
# 출산/육아용품        7537
# 모바일            4826
# 유아동의류          3554
# 침구/수예          3546
# 음료             3226
# 생활/주방가전        3013
# 가구             2971
# 식기/조리기구        2919
# 청소/세탁/욕실용품     2504
# 헬스/피트니스        2453
# 세제/위생          2281
# 문구/사무용품        1882
# 아웃도어/레저        1861
# 컴퓨터            1769
# 상품권            1714
# 주방잡화           1663
# 완구             1658
# 축산물            1155
# 과일             1077
# 구기/필드스포츠       1049
# 냉동식품            910
# 계절가전            743
# 냉장식품            571
# 영상/음향가전         468
# 인테리어/조명         355
# 냉장/세탁가전         273
# 자동차용품            96
# Name: CLAC1_NM, dtype: int64

# %%
print('\n*', 'Age:', 30, '대')
CPM_AGE_temp = CPM_AGE[CPM_AGE['CLNT_AGE'] == 30]
CPM_AGE_temp.iloc[:, 1].value_counts()
# Out:
# * Age: 30 대
# 여성의류          201601
# 화장품/뷰티케어      198252
# 스포츠패션         171715
# 패션잡화          165298
# 남성의류          163994
# 유아동의류         163665
# 속옷/양말/홈웨어     159899
# 출산/육아용품        87625
# 시즌스포츠          61118
# 퍼스널케어          45478
# 건강식품           40454
# 완구             29237
# 침구/수예          27530
# 원예/애완          27350
# 식기/조리기구        22897
# 문구/사무용품        16890
# 주방잡화           16556
# 세제/위생          15823
# 가구             15779
# 음료             15700
# 청소/세탁/욕실용품     15685
# 아웃도어/레저        14213
# 생활/주방가전        13904
# 헬스/피트니스         8621
# 모바일             7918
# 구기/필드스포츠        6586
# 과일              6023
# 컴퓨터             5814
# 상품권             4896
# 냉동식품            4040
# 계절가전            3855
# 냉장식품            3482
# 축산물             3189
# 인테리어/조명         2264
# 냉장/세탁가전         1939
# 영상/음향가전         1657
# 자동차용품            469
# Name: CLAC1_NM, dtype: int64

# %%
print('\n*', 'Age:', 40, '대')
CPM_AGE_temp = CPM_AGE[CPM_AGE['CLNT_AGE'] == 40]
CPM_AGE_temp.iloc[:, 1].value_counts()
# Out:
# * Age: 40 대
# 여성의류          252086
# 스포츠패션         190736
# 남성의류          181149
# 화장품/뷰티케어      146411
# 패션잡화          139822
# 속옷/양말/홈웨어     124259
# 유아동의류         111240
# 시즌스포츠          48925
# 퍼스널케어          41105
# 건강식품           36488
# 원예/애완          28940
# 식기/조리기구        27020
# 침구/수예          24695
# 출산/육아용품        23618
# 문구/사무용품        16940
# 음료             16076
# 주방잡화           15813
# 아웃도어/레저        15023
# 구기/필드스포츠       14003
# 세제/위생          13887
# 청소/세탁/욕실용품     13592
# 완구             13561
# 생활/주방가전        13057
# 가구             12248
# 과일              7910
# 헬스/피트니스         7853
# 모바일             6463
# 컴퓨터             6074
# 냉장식품            4969
# 계절가전            4889
# 냉동식품            4226
# 상품권             3075
# 축산물             2541
# 인테리어/조명         2512
# 냉장/세탁가전         2066
# 영상/음향가전         1354
# 자동차용품            340
# Name: CLAC1_NM, dtype: int64

# %%
print('\n*', 'Age:', 50, '대')
CPM_AGE_temp = CPM_AGE[CPM_AGE['CLNT_AGE'] == 50]
CPM_AGE_temp.iloc[:, 1].value_counts()
# Out:
# * Age: 50 대
# 여성의류          52946
# 스포츠패션         30072
# 남성의류          28424
# 화장품/뷰티케어      23008
# 패션잡화          21691
# 속옷/양말/홈웨어     17015
# 건강식품           8602
# 원예/애완          7378
# 퍼스널케어          6854
# 식기/조리기구        6481
# 침구/수예          4768
# 구기/필드스포츠       3548
# 주방잡화           3432
# 음료             3349
# 시즌스포츠          3289
# 아웃도어/레저        3239
# 청소/세탁/욕실용품     2623
# 가구             2607
# 생활/주방가전        2596
# 세제/위생          2589
# 유아동의류          2484
# 문구/사무용품        2372
# 과일             2283
# 냉장식품           1502
# 헬스/피트니스        1386
# 출산/육아용품        1378
# 컴퓨터            1136
# 계절가전           1121
# 모바일            1075
# 냉동식품            831
# 축산물             536
# 완구              530
# 냉장/세탁가전         475
# 인테리어/조명         418
# 상품권             369
# 영상/음향가전         253
# 자동차용품            69
# Name: CLAC1_NM, dtype: int64

# %%
print('\n*', 'Age:', 60, '대')
CPM_AGE_temp = CPM_AGE[CPM_AGE['CLNT_AGE'] == 60]
CPM_AGE_temp.iloc[:, 1].value_counts()
# Out:
# * Age: 60 대
# 패션잡화          6757
# 여성의류          5414
# 스포츠패션         4091
# 화장품/뷰티케어      3434
# 남성의류          2941
# 속옷/양말/홈웨어     2407
# 유아동의류         1316
# 건강식품          1175
# 원예/애완          958
# 퍼스널케어          780
# 식기/조리기구        674
# 출산/육아용품        640
# 침구/수예          613
# 시즌스포츠          585
# 아웃도어/레저        512
# 주방잡화           510
# 음료             461
# 과일             425
# 구기/필드스포츠       394
# 청소/세탁/욕실용품     363
# 문구/사무용품        358
# 세제/위생          335
# 생활/주방가전        318
# 가구             317
# 완구             281
# 냉장식품           238
# 컴퓨터            160
# 계절가전           152
# 냉동식품           144
# 헬스/피트니스        129
# 모바일            102
# 축산물             90
# 상품권             77
# 냉장/세탁가전         68
# 인테리어/조명         45
# 영상/음향가전         40
# 자동차용품            4
# Name: CLAC1_NM, dtype: int64

# %%
print('\n*', 'Age:', 70, '대')
CPM_AGE_temp = CPM_AGE[CPM_AGE['CLNT_AGE'] == 70]
CPM_AGE_temp.iloc[:, 1].value_counts()
# Out:
# * Age: 70 대
# 스포츠패션         911
# 여성의류          793
# 남성의류          685
# 화장품/뷰티케어      498
# 속옷/양말/홈웨어     427
# 패션잡화          420
# 유아동의류         283
# 원예/애완         185
# 건강식품          157
# 퍼스널케어         136
# 시즌스포츠          74
# 음료             70
# 주방잡화           64
# 과일             63
# 아웃도어/레저        57
# 세제/위생          53
# 청소/세탁/욕실용품     52
# 구기/필드스포츠       49
# 생활/주방가전        47
# 침구/수예          45
# 가구             44
# 식기/조리기구        39
# 완구             39
# 출산/육아용품        36
# 축산물            33
# 냉장식품           31
# 문구/사무용품        30
# 모바일            27
# 컴퓨터            25
# 계절가전           19
# 상품권            19
# 헬스/피트니스        18
# 냉동식품           14
# 영상/음향가전         9
# 냉장/세탁가전         9
# 인테리어/조명         9
# 자동차용품           1
# Name: CLAC1_NM, dtype: int64

# %%
print('\n*', 'Age:', 80, '대')
CPM_AGE_temp = CPM_AGE[CPM_AGE['CLNT_AGE'] == 80]
CPM_AGE_temp.iloc[:, 1].value_counts()
# Out:
# * Age: 80 대
# 화장품/뷰티케어      55
# 스포츠패션         49
# 남성의류          22
# 여성의류          17
# 속옷/양말/홈웨어     17
# 패션잡화          15
# 퍼스널케어         10
# 유아동의류         10
# 시즌스포츠          6
# 주방잡화           6
# 음료             6
# 침구/수예          5
# 구기/필드스포츠       5
# 출산/육아용품        4
# 가구             4
# 문구/사무용품        4
# 컴퓨터            3
# 계절가전           2
# 식기/조리기구        2
# 원예/애완          2
# 생활/주방가전        2
# 냉동식품           2
# 냉장/세탁가전        2
# 축산물            1
# 모바일            1
# 완구             1
# 건강식품           1
# 청소/세탁/욕실용품     1
# Name: CLAC1_NM, dtype: int64

# %%
for age in range(1, 8) :
    print('\n*', 'Age:', age*10, '대')
    CPM_AGE_temp = CPM_AGE[CPM_AGE['CLNT_AGE'] == age*10]
    CPM_AGE_temp.iloc[:, 1].value_counts().plot.bar()
    plt.show()
# Out:
# * Age: 10 대
# * Age: 20 대
# * Age: 30 대
# * Age: 40 대
# * Age: 50 대
# * Age: 60 대
# * Age: 70 대
