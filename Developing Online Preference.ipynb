# %% [markdown]
# # 1.온라인 선호지수 분석용 데이터 생성
# ## Search1과 Custom에 공통적으로 포함된 Client Id만으로 데이터프레임 생성

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import os

# %%
#데이터가져오기
Product = pd.read_csv("C:/Users/lsh93/Desktop/data/Product.csv")
Search1 = pd.read_csv("C:/Users/lsh93/Desktop/data/Search1.csv")
Search2 = pd.read_csv("C:/Users/lsh93/Desktop/data/Search2.csv")
Custom = pd.read_csv("C:/Users/lsh93/Desktop/data/Custom.csv")
Session = pd.read_csv("C:/Users/lsh93/Desktop/data/Session.csv")
Master = pd.read_csv("C:/Users/lsh93/Desktop/data/Master.csv")
# Out:
# C:\Users\lsh93\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#구매데이터의 client 수 != 고객데이터의 client 수 
#구매데이터의 client 수 != 검색데이터의 client 수
print('Product shape: ',Product.shape)
print('Custom shape: ',Custom.shape)
print('Search1 shape: ',Search1.shape)
print('Session shape: ',Session.shape)
print()
print('구매에 참여한 client 수: ',len(Product['CLNT_ID'].value_counts()))
print('고객데이터에 있는 unique한 client 수: ',len(Custom['CLNT_ID'].value_counts()))
print('세션에 참여한 unique한 client 수: ',len(Session['CLNT_ID'].value_counts()))
print('검색에 참여한 client 수: ', len(Search1['CLNT_ID'].value_counts()))
# Out:
# Product shape:  (5024906, 8)
# Custom shape:  (671679, 3)
# Search1 shape:  (2884943, 4)
# Session shape:  (2712907, 9)
#
# 구매에 참여한 client 수:  922737
# 고객데이터에 있는 unique한 client 수:  671679
# 세션에 참여한 unique한 client 수:  922737
# 검색에 참여한 client 수:  511477

# %% [markdown]
# - 세션에 참여한 client 수와 구매에 참여한 client 수는 동일하다
# - 상품을 구매했을지라도 검색을 하지 않은 client들이 있다 ) 922737 - 511477 만큼
# - 고객데이터에 모든 client들의 정보가 있는 것은 아니다

# %%
temp1 = pd.merge(Product,Session, how = 'inner' , on = 'CLNT_ID')

# %%
print(len(temp1['CLNT_ID'].value_counts()))
# Out:
# 922737

# %%
temp2 = pd.merge(Custom, Product, how = 'right' , on = 'CLNT_ID')

# %%
print(len(temp1['CLNT_ID'].value_counts()))
# Out:
# 922737

# %%
#null값 체크 --> 이건 unique한 건 아니지만 그래도 null값이 있다는 걸 의미함 
print(temp2['CLNT_AGE'].isnull().sum().sum())
# Out:
# 1036319

# %% [markdown]
# # Product Outlier 제거
# - 데이터 전처리 : outlier 제거
# - HIT_SEQ가 1인 것 제거하기

# %%
#HIT_SEQ가 1인 row 제거하기 (outlier로 간주하라고 하였음)
print('제거 전: ',len(Product['CLNT_ID'].value_counts()))  
idx = (Product['HITS_SEQ'] != 1) 
Product = Product[idx] 
print('제거 후: ',len(Product['CLNT_ID'].value_counts()))
# Out:
# 제거 전:  922737
# 제거 후:  922618

# %%
Product[Product['CLNT_ID'] == 4758889]
# Out:
#          CLNT_ID   SESS_ID  HITS_SEQ    PD_C         PD_ADD_NM PD_BRA_NM  \
# 533815   4758889  10607258        24  587541  색상:블랙|사이즈:F / 1개        비키
# 597057   4758889  10607258       195  587541  색상:블랙|사이즈:F / 1개        비키
# 655687   4758889  10607258       298  587541  색상:블랙|사이즈:F / 1개        비키
# 661037   4758889  10730334        76  692624        색상:블랙 / 1개      LG전자
# 4954520  4758889  10607258       298  776358       사이즈:28 / 1개     게스(진)
# 5022807  4758889  10607258       195  776358       사이즈:28 / 1개     게스(진)
#
#         PD_BUY_AM PD_BUY_CT
# 533815     45,000         1
# 597057     45,000         1
# 655687     45,000         1
# 661037     45,340         1
# 4954520    39,000         1
# 5022807    39,000         1

# %% [markdown]
# ## 1.1 상품 구매량 count를 위한 테이블 만들기

# %% [markdown]
# - 상품 구매 count를 하기 위해서, Product에서 HIT_SEQ = 1을 제거하고(앞에서 이미 제거됨), Search1과 custom에 둘 다 존재하는 Client 기준으로 정렬
# - 한 client의 hit번호가 가장 큰 것에 대해서만 따로 빼서 매트릭스를 만들고, 그 후 상품분류에 대해 value_counts()해 주면 될듯

# %%
#Search1과 custom의 공통된 client id 뽑고, unique하게 만들어주기
Client = pd.merge(Search1[['CLNT_ID']], Custom[['CLNT_ID']])
Unique_Client = Client.drop_duplicates(subset=None, keep='last', inplace=False)

# %%
Unique_Client['CLNT_ID'].value_counts()
# Out:
# 5461714    1
# 557637     1
# 5280327    1
# 5328413    1
# 2685514    1
# 6353483    1
# 4246092    1
# 4768333    1
# 55886      1
# 2150991    1
# 1583696    1
# 1581649    1
# 5767765    1
# 5773910    1
# 2365283    1
# 1079898    1
# 553563     1
# 5784157    1
# 6314590    1
# 6400608    1
# 2380969    1
# 2136646    1
# 3191363    1
# 4842089    1
# 2772219    1
# 4954662    1
# 2855463    1
# 2353704    1
# 1303081    1
# 5857480    1
#           ..
# 4580630    1
# 2987288    1
# 2465049    1
# 4762753    1
# 6130971    1
# 1081954    1
# 4589347    1
# 5615932    1
# 4015362    1
# 4740254    1
# 1896362    1
# 1211621    1
# 6448358    1
# 1532795    1
# 5179014    1
# 3592504    1
# 4859118    1
# 3331312    1
# 5954801    1
# 6487285    1
# 5141990    1
# 4908278    1
# 6505990    1
# 2266360    1
# 5938425    1
# 6448371    1
# 4371708    1
# 3319038    1
# 6466815    1
# 6291456    1
# Name: CLNT_ID, Length: 375864, dtype: int64

# %%
#Search1과 custom에 공통으로 있는 client id에 해당하는 구매내역만 dataframe으로 만들기 
Product_Client = pd.merge(Product, Unique_Client, how = 'inner', on = 'CLNT_ID')
print(len(Product_Client['CLNT_ID'].value_counts()))
# Out:
# 375864

# %%
#Product_Client = Product_Client.drop_duplicates(subset=None, keep='last', inplace=False)
#print(len(Product_Client['CLNT_ID'].value_counts()))
# Out:
# 375864

# %%
Product_Client[Product_Client['CLNT_ID']==4140076]
# Out:
#     CLNT_ID   SESS_ID  HITS_SEQ    PD_C                            PD_ADD_NM  \
# 0   4140076  10189797        13  570603     색상:BLK0_(BLK0)BLACK|사이즈:120 / 2개
# 1   4140076  10342512        23  422358  선택:02.204143-02S|사이즈:M5W7(240) / 1개
# 2   4140076   6526651        22  196272      색상:선택3)248(네이비)|사이즈:L(105) / 1개
# 3   4140076   8326529       199  305965                     사이즈:115_3XL / 1개
# 4   4140076   8891563        19  305965                     사이즈:115_3XL / 1개
# 5   4140076   6526651       193  196272      색상:선택2)102(블랙)|사이즈:XL(110) / 1개
# 6   4140076   6591360       149  196272      색상:선택2)102(블랙)|사이즈:XL(110) / 2개
# 7   4140076   6526651        22  365025                   색상:WH|사이즈:165 / 1개
# 8   4140076   4756252       147  794908                                   1개
# 9   4140076  10342512        23  403243                          사이즈:M9 / 1개
# 10  4140076   9147546       474  544957                                   1개
# 11  4140076   6526651        22  364992                   색상:BG|사이즈:165 / 1개
# 12  4140076   6591360       149  628713               사이즈:M7(260mm)_620 / 1개
# 13  4140076  10574005       253  450131                  색상:BLK|사이즈:080 / 1개
# 14  4140076   9147546       462  533783                     사이즈:XL(110) / 1개
# 15  4140076   6526651        22  339321                   색상:BU|사이즈:165 / 1개
# 16  4140076  10767546        19  600758                      사이즈:L(105) / 1개
# 17  4140076  10767546        19  471477                         사이즈:165 / 1개
# 18  4140076   7754761        71  315988     색상:DG(다크그레이)|사이즈:FREE(원사이즈) / 1개
# 19  4140076   6517872       179  373461  품번:03.FITFLOP_J55_001_|사이즈:230 / 1개
# 20  4140076   5338950        76  598881                                   1개
# 21  4140076  10883079        29  689663                색상:그레이|직접입력1:240 / 1개
# 22  4140076  10584304        50  689663                색상:그레이|직접입력1:235 / 1개
# 23  4140076  10760242        26  689663                색상:그레이|직접입력1:240 / 1개
# 24  4140076   6885554       134  288192                 색상:아이보리|사이즈:110 / 1개
# 25  4140076   6885554       118  522552                색상:아이보리|Size:110 / 1개
# 26  4140076   9992238       112  495110                         SIZE:XL / 1개
# 27  4140076   8153697       123  555694             색상:화이트|사이즈:007(110) / 1개
# 28  4140076   6591360       149  526369                         사이즈:XXL / 1개
# 29  4140076  10342512        23  806382  색상:202356-159오이스터|사이즈:C06[155] / 1개
# 30  4140076   4756252        76  570089                                   1개
# 31  4140076   2051362        76  195687                      사이즈:L(105) / 1개
# 32  4140076   6538217        26  739858                                   1개
# 33  4140076   9899980        34  606095                           사이즈:3 / 1개
# 34  4140076   7782189       125  606096                           사이즈:3 / 1개
# 35  4140076  10574005       253  481952           구성:팬티3매|사이즈:80/11~12세 / 1개
# 36  4140076   6526651       193  507637              색상:블랙(BLK)|사이즈:XXL / 1개
# 37  4140076   6591360       149  507637              색상:블랙(BLK)|사이즈:XXL / 1개
# 38  4140076   8608110       366  447887                     사이즈:120_4XL / 2개
# 39  4140076   8235168       135  447887                     사이즈:120_4XL / 2개
# 40  4140076   8891563        19  447887                     사이즈:120_4XL / 2개
# 41  4140076   8326529       199  447887                     사이즈:120_4XL / 2개
# 42  4140076   5384543        45  489476                                   1개
# 43  4140076  10189797        13  411029   품번/사이즈:CY4574_회흰 / 120(XXXXL) / 1개
# 44  4140076   6526651       193  262956                         사이즈:280 / 1개
# 45  4140076   8608110       366  567645                     사이즈:115_3XL / 1개
# 46  4140076   8235168       135  275704                        SIZE:3XL / 1개
# 47  4140076   8235168       135  567645                     사이즈:115_3XL / 1개
# 48  4140076   8326529       199  275704                        SIZE:3XL / 1개
# 49  4140076  10574005       253  670971                   색상:블루|사이즈:220 / 1개
# 50  4140076   8608110       366  447893                     사이즈:115_3XL / 1개
# 51  4140076   7803570        51  453110                    색상:블랙|사이즈:66 / 1개
#
#        PD_BRA_NM PD_BUY_AM PD_BUY_CT
# 0            데상트    39,000         2
# 1            크록스    39,900         1
# 2          프레드페리    47,600         1
# 3       아디다스(의류)    46,700         1
# 4       아디다스(의류)    46,700         1
# 5          프레드페리    47,600         1
# 6          프레드페리    47,600         2
# 7          닥스 키즈    48,300         1
# 8          네이쳐리빙     7,200         1
# 9            크록스    57,000         1
# 10           영실업    59,820         1
# 11         닥스 키즈    71,200         1
# 12           크록스    69,900         1
# 13      아레나(수영복)    79,200         1
# 14         프레드페리    85,000         1
# 15         닥스 키즈    90,300         1
# 16         프레드페리   103,600         1
# 17         닥스 키즈   116,100         1
# 18           시슬리    99,000         1
# 19      핏플랍(여성화)   118,000         1
# 20       쌤소나이트레드   111,000         1
# 21         슈퍼콤마비   125,300         1
# 22         슈퍼콤마비   125,300         1
# 23         슈퍼콤마비   125,300         1
# 24            빈폴   148,000         1
# 25            빈폴   148,000         1
# 26        스톤아일랜드   149,000         1
# 27         파리게이츠   238,000         1
# 28        스톤아일랜드   219,000         1
# 29           크록스    16,000         1
# 30           데코뷰    16,600         1
# 31         프레드페리   229,600         1
# 32  엠포리오아르마니(시계)   290,000         1
# 33          톰브라운   432,000         1
# 34          톰브라운   487,000         1
# 35          프레비니    18,000         1
# 36       게스(VIP)    23,800         1
# 37       게스(VIP)    23,800         1
# 38      아디다스(의류)    25,400         2
# 39      아디다스(의류)    25,400         2
# 40      아디다스(의류)    25,400         2
# 41      아디다스(의류)    25,400         2
# 42           데코뷰    29,000         1
# 43      아디다스(의류)    29,000         1
# 44           나이키    29,000         1
# 45      아디다스(의류)    30,900         1
# 46      아디다스(의류)    31,000         1
# 47      아디다스(의류)    30,900         1
# 48      아디다스(의류)    31,000         1
# 49   노스페이스키즈(아동)    31,200         1
# 50      아디다스(의류)    38,800         1
# 51           리스트    39,000         1

# %% [markdown]
# ## 1.2 Client Behavior 데이터 만들기

# %% [markdown]
# #### Client의 행동을 따라가보자
# - Client가 어떻게 행동하는지 데이터 살펴보기
# - Client Behavior 데이터 만들기

# %% [markdown]
# - Client ID, 날짜(세션일자), 세션 ID, HIT번호, 검색키워드, 검색건수, 상품명, 구매건수
#
# - CLNT_ID(Product), SESS_DT(Session), SESS_ID(세션ID), HITS_SEQ(Product)
# - KWD_NM(Search1), SEARCH_CNT(Search1), PD_NM(Master), PD_BUY_CT(Product)
#
# #### Search1의 client < custom의 client < Product의 client = Session의 Client
# #### Search1의 client 중에 custom 정보 없는 것 있다.
# #### 검색을 하고, custom 정보가 있는 client만을 기준으로 table 작성 (375864개의 client id)

# %%
Product_Client.head()
# Out:
#    CLNT_ID   SESS_ID  HITS_SEQ    PD_C                            PD_ADD_NM  \
# 0  4140076  10189797        13  570603     색상:BLK0_(BLK0)BLACK|사이즈:120 / 2개
# 1  4140076  10342512        23  422358  선택:02.204143-02S|사이즈:M5W7(240) / 1개
# 2  4140076   6526651        22  196272      색상:선택3)248(네이비)|사이즈:L(105) / 1개
# 3  4140076   8326529       199  305965                     사이즈:115_3XL / 1개
# 4  4140076   8891563        19  305965                     사이즈:115_3XL / 1개
#
#   PD_BRA_NM PD_BUY_AM PD_BUY_CT
# 0       데상트    39,000         2
# 1       크록스    39,900         1
# 2     프레드페리    47,600         1
# 3  아디다스(의류)    46,700         1
# 4  아디다스(의류)    46,700         1

# %%
data1 = pd.merge(Product_Client, Session)
print(len(data1['CLNT_ID'].value_counts()))
# Out:
# 375864

# %%
#상품정보를 추가해준다
data2 = pd.merge(data1, Master, how = 'inner', on = 'PD_C')
print(len(data2['CLNT_ID'].value_counts()))
# Out:
# 375864

# %%
#세션아이디도 동일한 것으로
#client -> 검색 -> 구매
Client_Behavior = pd.merge(data2, Search1, on=['CLNT_ID', 'SESS_ID'])
print(len(Client_Behavior['CLNT_ID'].value_counts()))
print('CLNT_ID랑 SESS_ID가 동일해야 하는 조건 때문에 client 수 약간 줄어들었음.')
# Out:
# 375839
# CLNT_ID랑 SESS_ID가 동일해야 하는 조건 때문에 client 수 약간 줄어들었음.

# %%
Client_Behavior
# Out:
#          CLNT_ID   SESS_ID  HITS_SEQ    PD_C  \
# 0        4140076  10342512        23  422358
# 1        4140076  10342512        23  403243
# 2        4140076  10342512        23  806382
# 3        4140076   6526651        22  196272
# 4        4140076   6526651        22  196272
# 5        4140076   6526651        22  196272
# 6        4140076   6526651        22  196272
# 7        4140076   6526651       193  196272
# 8        4140076   6526651       193  196272
# 9        4140076   6526651       193  196272
# 10       4140076   6526651       193  196272
# 11       4140076   6526651        22  365025
# 12       4140076   6526651        22  365025
# 13       4140076   6526651        22  365025
# 14       4140076   6526651        22  365025
# 15       4140076   6526651        22  364992
# 16       4140076   6526651        22  364992
# 17       4140076   6526651        22  364992
# 18       4140076   6526651        22  364992
# 19       4140076   6526651        22  339321
# 20       4140076   6526651        22  339321
# 21       4140076   6526651        22  339321
# 22       4140076   6526651        22  339321
# 23       4140076   6526651       193  507637
# 24       4140076   6526651       193  507637
# 25       4140076   6526651       193  507637
# 26       4140076   6526651       193  507637
# 27       4140076   6526651       193  262956
# 28       4140076   6526651       193  262956
# 29       4140076   6526651       193  262956
# ...          ...       ...       ...     ...
# 4883474  5010268   8741152        33  636556
# 4883475  1082242   5661700        58  179401
# 4883476  1082242   5661700        58  179401
# 4883477   372204   5634118        48  403151
# 4883478  3650646  10447349        33  563577
# 4883479  5033434   4390462        75  507859
# 4883480  3853640  10507265        54  687956
# 4883481  3853640  10507265        54  687956
# 4883482  4809147   7145157        63  224460
# 4883483  4809147   7145157        63  224460
# 4883484  4809147   7145157        63  224460
# 4883485  4809147   7186972        47  224460
# 4883486  5601778   8217108       130  423262
# 4883487  5601778   8217108        91  423262
# 4883488   901964      8750       285   15477
# 4883489   901964      8750       285   15477
# 4883490   901964      8750       285   15477
# 4883491  1454857   9954443        26  816627
# 4883492  1337534  10680863        53  419179
# 4883493  4110447   5212278        90  636556
# 4883494  4110447   6192376       114  391199
# 4883495  4926545   9037714        54  455563
# 4883496  5072758   8571308        27  819710
# 4883497  2644758   6806773        21  388660
# 4883498  5085969  10609581        48  590876
# 4883499  5085969  10609581        48  590876
# 4883500  5085969  10609581        48  590876
# 4883501  3235159  10660304        94    3253
# 4883502  4108900   2967180        27  642112
# 4883503  4108900   2967180        56  642112
#
#                                    PD_ADD_NM     PD_BRA_NM PD_BUY_AM  \
# 0        선택:02.204143-02S|사이즈:M5W7(240) / 1개           크록스    39,900
# 1                                사이즈:M9 / 1개           크록스    57,000
# 2        색상:202356-159오이스터|사이즈:C06[155] / 1개           크록스    16,000
# 3            색상:선택3)248(네이비)|사이즈:L(105) / 1개         프레드페리    47,600
# 4            색상:선택3)248(네이비)|사이즈:L(105) / 1개         프레드페리    47,600
# 5            색상:선택3)248(네이비)|사이즈:L(105) / 1개         프레드페리    47,600
# 6            색상:선택3)248(네이비)|사이즈:L(105) / 1개         프레드페리    47,600
# 7            색상:선택2)102(블랙)|사이즈:XL(110) / 1개         프레드페리    47,600
# 8            색상:선택2)102(블랙)|사이즈:XL(110) / 1개         프레드페리    47,600
# 9            색상:선택2)102(블랙)|사이즈:XL(110) / 1개         프레드페리    47,600
# 10           색상:선택2)102(블랙)|사이즈:XL(110) / 1개         프레드페리    47,600
# 11                        색상:WH|사이즈:165 / 1개         닥스 키즈    48,300
# 12                        색상:WH|사이즈:165 / 1개         닥스 키즈    48,300
# 13                        색상:WH|사이즈:165 / 1개         닥스 키즈    48,300
# 14                        색상:WH|사이즈:165 / 1개         닥스 키즈    48,300
# 15                        색상:BG|사이즈:165 / 1개         닥스 키즈    71,200
# 16                        색상:BG|사이즈:165 / 1개         닥스 키즈    71,200
# 17                        색상:BG|사이즈:165 / 1개         닥스 키즈    71,200
# 18                        색상:BG|사이즈:165 / 1개         닥스 키즈    71,200
# 19                        색상:BU|사이즈:165 / 1개         닥스 키즈    90,300
# 20                        색상:BU|사이즈:165 / 1개         닥스 키즈    90,300
# 21                        색상:BU|사이즈:165 / 1개         닥스 키즈    90,300
# 22                        색상:BU|사이즈:165 / 1개         닥스 키즈    90,300
# 23                   색상:블랙(BLK)|사이즈:XXL / 1개       게스(VIP)    23,800
# 24                   색상:블랙(BLK)|사이즈:XXL / 1개       게스(VIP)    23,800
# 25                   색상:블랙(BLK)|사이즈:XXL / 1개       게스(VIP)    23,800
# 26                   색상:블랙(BLK)|사이즈:XXL / 1개       게스(VIP)    23,800
# 27                              사이즈:280 / 1개           나이키    29,000
# 28                              사이즈:280 / 1개           나이키    29,000
# 29                              사이즈:280 / 1개           나이키    29,000
# ...                                      ...           ...       ...
# 4883474                컬러:화이트 0806mpsnW / 1개    메트로시티(주얼리)    39,000
# 4883475                                   1개           미코우    39,800
# 4883476                                   1개           미코우    39,800
# 4883477   색상:02_BLACK(Z060)|사이즈:W6(230) / 1개           크록스    39,900
# 4883478                   색상:블랙|사이즈:280 / 1개         디스커버리    39,000
# 4883479                           색상:블랙 / 1개      뉴발란스(키즈)    39,000
# 4883480                                   1개           빌리프    39,000
# 4883481                                   1개           빌리프    39,000
# 4883482                                   1개           비오템    39,000
# 4883483                                   1개           비오템    39,000
# 4883484                                   1개           비오템    39,000
# 4883485                                   1개           비오템    39,000
# 4883486      색상:캔디핑크_204994-6X0|사이즈:160 / 1개         크록스키즈    39,500
# 4883487      색상:캔디핑크_204994-6X0|사이즈:155 / 1개         크록스키즈    39,500
# 4883488                  컬러:차콜그레이|치수:90 / 1개          클라이드    39,900
# 4883489                  컬러:차콜그레이|치수:90 / 1개          클라이드    39,900
# 4883490                  컬러:차콜그레이|치수:90 / 1개          클라이드    39,900
# 4883491                                   1개          고려은단    39,900
# 4883492                    색상:BLU|사이즈:M / 1개     아메리칸이글(진)    39,900
# 4883493                 컬러:핑크 0806mpsnP / 1개    메트로시티(주얼리)    39,000
# 4883494                모델명:10. 0806mpnP / 1개    메트로시티(주얼리)    39,000
# 4883495              사이즈:ML10(66)|색상:다크 / 1개           밸리걸    39,900
# 4883496                                   3개       농협홍삼한삼인    39,900
# 4883497                   색상:블루|사이즈:130 / 1개       크록스(키즈)    39,900
# 4883498                모델명:26_0373mpbrP / 1개    메트로시티(주얼리)    39,000
# 4883499                모델명:26_0373mpbrP / 1개    메트로시티(주얼리)    39,000
# 4883500                모델명:26_0373mpbrP / 1개    메트로시티(주얼리)    39,000
# 4883501                                   1개  필립스(PHILIPS)    39,000
# 4883502                          색상:카바나 / 1개         바비브라운    39,000
# 4883503                          색상:카바나 / 1개         바비브라운    39,000
#
#         PD_BUY_CT  SESS_SEQ   SESS_DT    ...      TOT_SESS_HR_V DVC_CTG_NM  \
# 0               1       156  20180411    ...                873     mobile
# 1               1       156  20180411    ...                873     mobile
# 2               1       156  20180411    ...                873     mobile
# 3               1       272  20180613    ...              2,147     mobile
# 4               1       272  20180613    ...              2,147     mobile
# 5               1       272  20180613    ...              2,147     mobile
# 6               1       272  20180613    ...              2,147     mobile
# 7               1       272  20180613    ...              2,147     mobile
# 8               1       272  20180613    ...              2,147     mobile
# 9               1       272  20180613    ...              2,147     mobile
# 10              1       272  20180613    ...              2,147     mobile
# 11              1       272  20180613    ...              2,147     mobile
# 12              1       272  20180613    ...              2,147     mobile
# 13              1       272  20180613    ...              2,147     mobile
# 14              1       272  20180613    ...              2,147     mobile
# 15              1       272  20180613    ...              2,147     mobile
# 16              1       272  20180613    ...              2,147     mobile
# 17              1       272  20180613    ...              2,147     mobile
# 18              1       272  20180613    ...              2,147     mobile
# 19              1       272  20180613    ...              2,147     mobile
# 20              1       272  20180613    ...              2,147     mobile
# 21              1       272  20180613    ...              2,147     mobile
# 22              1       272  20180613    ...              2,147     mobile
# 23              1       272  20180613    ...              2,147     mobile
# 24              1       272  20180613    ...              2,147     mobile
# 25              1       272  20180613    ...              2,147     mobile
# 26              1       272  20180613    ...              2,147     mobile
# 27              1       272  20180613    ...              2,147     mobile
# 28              1       272  20180613    ...              2,147     mobile
# 29              1       272  20180613    ...              2,147     mobile
# ...           ...       ...       ...    ...                ...        ...
# 4883474         1        22  20180508    ...                490     mobile
# 4883475         1        16  20180627    ...              1,631     mobile
# 4883476         1        16  20180627    ...              1,631     mobile
# 4883477         1         6  20180628    ...                479     mobile
# 4883478         1       256  20180409    ...                208     mobile
# 4883479         1        23  20180718    ...                881     mobile
# 4883480         1        55  20180408    ...              1,916     mobile
# 4883481         1        55  20180408    ...              1,916     mobile
# 4883482         1       134  20180603    ...                747     mobile
# 4883483         1       134  20180603    ...                747     mobile
# 4883484         1       134  20180603    ...                747     mobile
# 4883485         1       133  20180602    ...                289     mobile
# 4883486         1         3  20180516    ...              2,213     mobile
# 4883487         1         3  20180516    ...              2,213     mobile
# 4883488         1        24  20180930    ...              3,118     mobile
# 4883489         1        24  20180930    ...              3,118     mobile
# 4883490         1        24  20180930    ...              3,118     mobile
# 4883491         1        26  20180417    ...                651     mobile
# 4883492         1        76  20180405    ...                499     mobile
# 4883493         1         6  20180705    ...              1,605     mobile
# 4883494         1         3  20180619    ...              1,558     mobile
# 4883495         1         6  20180502    ...                174     mobile
# 4883496         3        36  20180510    ...                275     mobile
# 4883497         1         4  20180608    ...                868     mobile
# 4883498         1        82  20180406    ...              7,026     mobile
# 4883499         1        82  20180406    ...              7,026     mobile
# 4883500         1        82  20180406    ...              7,026     mobile
# 4883501         1        29  20180406    ...              1,593     mobile
# 4883502         1        34  20180811    ...                371     mobile
# 4883503         1        34  20180811    ...                371     mobile
#
#                     ZON_NM      CITY_NM  \
# 0              Gyeonggi-do   Gwangju-si
# 1              Gyeonggi-do   Gwangju-si
# 2              Gyeonggi-do   Gwangju-si
# 3                    Seoul        Seoul
# 4                    Seoul        Seoul
# 5                    Seoul        Seoul
# 6                    Seoul        Seoul
# 7                    Seoul        Seoul
# 8                    Seoul        Seoul
# 9                    Seoul        Seoul
# 10                   Seoul        Seoul
# 11                   Seoul        Seoul
# 12                   Seoul        Seoul
# 13                   Seoul        Seoul
# 14                   Seoul        Seoul
# 15                   Seoul        Seoul
# 16                   Seoul        Seoul
# 17                   Seoul        Seoul
# 18                   Seoul        Seoul
# 19                   Seoul        Seoul
# 20                   Seoul        Seoul
# 21                   Seoul        Seoul
# 22                   Seoul        Seoul
# 23                   Seoul        Seoul
# 24                   Seoul        Seoul
# 25                   Seoul        Seoul
# 26                   Seoul        Seoul
# 27                   Seoul        Seoul
# 28                   Seoul        Seoul
# 29                   Seoul        Seoul
# ...                    ...          ...
# 4883474        Gyeonggi-do     Suwon-si
# 4883475        Gyeonggi-do    Yongin-si
# 4883476        Gyeonggi-do    Yongin-si
# 4883477            Incheon      Incheon
# 4883478              Daegu        Daegu
# 4883479              Ulsan        Ulsan
# 4883480              Seoul        Seoul
# 4883481              Seoul        Seoul
# 4883482              Seoul        Seoul
# 4883483              Seoul        Seoul
# 4883484              Seoul        Seoul
# 4883485              Seoul        Seoul
# 4883486              Seoul        Seoul
# 4883487              Seoul        Seoul
# 4883488              Seoul        Seoul
# 4883489              Seoul        Seoul
# 4883490              Seoul        Seoul
# 4883491              Busan        Busan
# 4883492              Daegu        Daegu
# 4883493              Seoul        Seoul
# 4883494              Seoul        Seoul
# 4883495              Seoul        Seoul
# 4883496  Chungcheongbuk-do  Cheongju-si
# 4883497              Seoul        Seoul
# 4883498              Seoul        Seoul
# 4883499              Seoul        Seoul
# 4883500              Seoul        Seoul
# 4883501              Seoul        Seoul
# 4883502              Seoul        Seoul
# 4883503              Seoul        Seoul
#
#                                                      PD_NM  CLAC1_NM  \
# 0        크록스 모디스포츠 클로그 2종 / 스포츠샌들 - 02.204143-02S / M8/...     스포츠패션
# 1        크록스 스위프트워터 맨즈 데크 클로그 네이비/화이트 (CROCS SWIFTWATER...     스포츠패션
# 2        [크록스] 아동 샌들/플랫/슬리퍼 202887 202882 202707 269697...     시즌스포츠
# 3        [S/S상품]크루넥 티셔츠 4종 AFPM6334-4종 - 선택4)314(회색) / ...      남성의류
# 4        [S/S상품]크루넥 티셔츠 4종 AFPM6334-4종 - 선택4)314(회색) / ...      남성의류
# 5        [S/S상품]크루넥 티셔츠 4종 AFPM6334-4종 - 선택4)314(회색) / ...      남성의류
# 6        [S/S상품]크루넥 티셔츠 4종 AFPM6334-4종 - 선택4)314(회색) / ...      남성의류
# 7        [S/S상품]크루넥 티셔츠 4종 AFPM6334-4종 - 선택4)314(회색) / ...      남성의류
# 8        [S/S상품]크루넥 티셔츠 4종 AFPM6334-4종 - 선택4)314(회색) / ...      남성의류
# 9        [S/S상품]크루넥 티셔츠 4종 AFPM6334-4종 - 선택4)314(회색) / ...      남성의류
# 10       [S/S상품]크루넥 티셔츠 4종 AFPM6334-4종 - 선택4)314(회색) / ...      남성의류
# 11                 BASIC솔리드R넥티셔츠(DOM10TR18M_WT) - WH / 120     유아동의류
# 12                 BASIC솔리드R넥티셔츠(DOM10TR18M_WT) - WH / 120     유아동의류
# 13                 BASIC솔리드R넥티셔츠(DOM10TR18M_WT) - WH / 120     유아동의류
# 14                 BASIC솔리드R넥티셔츠(DOM10TR18M_WT) - WH / 120     유아동의류
# 15                        5부치노팬츠(DOM12PS30M_BG) - BG / 130     유아동의류
# 16                        5부치노팬츠(DOM12PS30M_BG) - BG / 130     유아동의류
# 17                        5부치노팬츠(DOM12PS30M_BG) - BG / 130     유아동의류
# 18                        5부치노팬츠(DOM12PS30M_BG) - BG / 130     유아동의류
# 19                        체크반팔셔츠(DOM10XS22M_BU) - BU / 130     유아동의류
# 20                        체크반팔셔츠(DOM10XS22M_BU) - BU / 130     유아동의류
# 21                        체크반팔셔츠(DOM10XS22M_BU) - BU / 130     유아동의류
# 22                        체크반팔셔츠(DOM10XS22M_BU) - BU / 130     유아동의류
# 23        남성 미니 GUESS 포켓 V넥 반팔티셔츠(MI2K9417) - 화이트(WHT) / M      남성의류
# 24        남성 미니 GUESS 포켓 V넥 반팔티셔츠(MI2K9417) - 화이트(WHT) / M      남성의류
# 25        남성 미니 GUESS 포켓 V넥 반팔티셔츠(MI2K9417) - 화이트(WHT) / M      남성의류
# 26        남성 미니 GUESS 포켓 V넥 반팔티셔츠(MI2K9417) - 화이트(WHT) / M      남성의류
# 27                                     카와 832528-001 - 280     스포츠패션
# 28                                     카와 832528-001 - 280     스포츠패션
# 29                                     카와 832528-001 - 280     스포츠패션
# ...                                                    ...       ...
# 4883474                    목걸이 0806mpsnPWY - 화이트 0806mpsnW      패션잡화
# 4883475                    MIKOU 미코우 접이식 아동용 발광 킥보드 (쿨스토리)   아웃도어/레저
# 4883476                    MIKOU 미코우 접이식 아동용 발광 킥보드 (쿨스토리)   아웃도어/레저
# 4883477  크록스공식 여성 레이웨지 2종택1(18SS11382) - 01_OATMEAL(Z14...     시즌스포츠
# 4883478                         DXSH71831 마크슬리퍼 - 핑크 / 280   아웃도어/레저
# 4883479              경량 미아방지가방(XS)/유아동키즈가방/NK8A8S503U - 핑크      패션잡화
# 4883480                                 UV프로텍터 멀티선스크린 60ml  화장품/뷰티케어
# 4883481                                 UV프로텍터 멀티선스크린 60ml  화장품/뷰티케어
# 4883482                          (6월)NEW UV 디펜스 선스틱 20g 세트  화장품/뷰티케어
# 4883483                          (6월)NEW UV 디펜스 선스틱 20g 세트  화장품/뷰티케어
# 4883484                          (6월)NEW UV 디펜스 선스틱 20g 세트  화장품/뷰티케어
# 4883485                          (6월)NEW UV 디펜스 선스틱 20g 세트  화장품/뷰티케어
# 4883486  [#텐텐]크록밴드 미키 펀랩 라이트 6종 디자인선택 - 캔디핑크_204994-6X0...      패션잡화
# 4883487  [#텐텐]크록밴드 미키 펀랩 라이트 6종 디자인선택 - 캔디핑크_204994-6X0...      패션잡화
# 4883488            로운 남여공용 플라이 롱 집업점퍼 FIAJP161U - 핑크 / 110      남성의류
# 4883489            로운 남여공용 플라이 롱 집업점퍼 FIAJP161U - 핑크 / 110      남성의류
# 4883490            로운 남여공용 플라이 롱 집업점퍼 FIAJP161U - 핑크 / 110      남성의류
# 4883491                         [본사직영] 고려은단 비타민C 1000 600정      건강식품
# 4883492  [여성] 모달 스모크 스트라이프 블라우스 AFMS1HC8116A 400 - BLU ...      남성의류
# 4883493                    목걸이 0806mpsnPWY - 화이트 0806mpsnW      패션잡화
# 4883494       ★빠른배송★ 팔찌&발찌 강추아이템 20종 (한정사은품) - 17. 306hmeP      패션잡화
# 4883495                데님 덩가리 원피스 (972730) - ML10(66) / 다크      여성의류
# 4883496                                홍삼정 굿데이스틱 60포/쇼핑백증정      건강식품
# 4883497                소매 배색 래쉬가드세트_CBH2SS402S - 네이비 / 120     유아동의류
# 4883498  ★빠른배송★ 두근두근 설레이는 30종 주얼리 - 07_0819mpbrW(남성용)+2...      패션잡화
# 4883499  ★빠른배송★ 두근두근 설레이는 30종 주얼리 - 07_0819mpbrW(남성용)+2...      패션잡화
# 4883500  ★빠른배송★ 두근두근 설레이는 30종 주얼리 - 07_0819mpbrW(남성용)+2...      패션잡화
# 4883501                  헤어드라이어기  HP-8232 [2200W 고출력 드라이기]   생활/주방가전
# 4883502                                      크러쉬드 립칼라 - 플럼  화장품/뷰티케어
# 4883503                                      크러쉬드 립칼라 - 플럼  화장품/뷰티케어
#
#                CLAC2_NM       CLAC3_NM          KWD_NM SEARCH_CNT
# 0                남성스포츠화    남성스포츠샌들/슬리퍼             크록스          1
# 1                남성스포츠화    남성스포츠샌들/슬리퍼             크록스          1
# 2                수영/물놀이          아쿠아슈즈             크록스          1
# 3                남성의류상의          남성티셔츠          나이키슬리퍼          1
# 4                남성의류상의          남성티셔츠        프레드페리 남성          2
# 5                남성의류상의          남성티셔츠           게스 남성          1
# 6                남성의류상의          남성티셔츠            빈폴남성          1
# 7                남성의류상의          남성티셔츠          나이키슬리퍼          1
# 8                남성의류상의          남성티셔츠        프레드페리 남성          2
# 9                남성의류상의          남성티셔츠           게스 남성          1
# 10               남성의류상의          남성티셔츠            빈폴남성          1
# 11               유아의류상의       영유아티셔츠/탑          나이키슬리퍼          1
# 12               유아의류상의       영유아티셔츠/탑        프레드페리 남성          2
# 13               유아의류상의       영유아티셔츠/탑           게스 남성          1
# 14               유아의류상의       영유아티셔츠/탑            빈폴남성          1
# 15               남아의류하의           남아바지          나이키슬리퍼          1
# 16               남아의류하의           남아바지        프레드페리 남성          2
# 17               남아의류하의           남아바지           게스 남성          1
# 18               남아의류하의           남아바지            빈폴남성          1
# 19               유아의류상의        영유아남방셔츠          나이키슬리퍼          1
# 20               유아의류상의        영유아남방셔츠        프레드페리 남성          2
# 21               유아의류상의        영유아남방셔츠           게스 남성          1
# 22               유아의류상의        영유아남방셔츠            빈폴남성          1
# 23               남성의류상의          남성티셔츠          나이키슬리퍼          1
# 24               남성의류상의          남성티셔츠        프레드페리 남성          2
# 25               남성의류상의          남성티셔츠           게스 남성          1
# 26               남성의류상의          남성티셔츠            빈폴남성          1
# 27               여성스포츠화    여성스포츠샌들/슬리퍼          나이키슬리퍼          1
# 28               여성스포츠화    여성스포츠샌들/슬리퍼        프레드페리 남성          2
# 29               여성스포츠화    여성스포츠샌들/슬리퍼           게스 남성          1
# ...                 ...            ...             ...        ...
# 4883474              보석            목걸이       메트로시티 귀걸이          1
# 4883475  인라인/스케이트보드/킥보드     스케이트보드/킥보드           여성티셔츠          1
# 4883476  인라인/스케이트보드/킥보드     스케이트보드/킥보드          여성블라우스          1
# 4883477          수영/물놀이          아쿠아슈즈          크록스 여성          1
# 4883478              등산            등산화       디스커버리 슬리퍼          2
# 4883479           캐쥬얼가방          아동용가방          크록스 키즈          1
# 4883480             선케어           선크림류        빌리프 선스크린          1
# 4883481             선케어           선크림류         롯데카드vip          1
# 4883482            남성케어       남성스킨케어세트           비오템옴므          1
# 4883483            남성케어       남성스킨케어세트           키엘 남성          1
# 4883484            남성케어       남성스킨케어세트              키엘          1
# 4883485            남성케어       남성스킨케어세트           비오템옴므          2
# 4883486            유아동화          유아동샌들          크록스 키즈          2
# 4883487            유아동화          유아동샌들          크록스 키즈          2
# 4883488         남성의류아우터           남성점퍼          기모후드집업          1
# 4883489         남성의류아우터           남성점퍼            네오플렌          1
# 4883490         남성의류아우터           남성점퍼            여성점퍼          1
# 4883491             영양제          일반비타민  고려은단 비타민C 1000          3
# 4883492          남성의류상의          남성티셔츠         스모크블라우스          1
# 4883493              보석            목걸이           메트로시티          4
# 4883494              보석             발찌       메트로시티 목걸이          4
# 4883495          여성의류전신          여성원피스             밸리걸          2
# 4883496       홍삼/인삼가공식품       홍삼정/분말/환           굿데이스틱          1
# 4883497          남아의류세트         남아의류세트      아동 래쉬가드 남아          1
# 4883498              보석            목걸이             끄란느          1
# 4883499              보석            목걸이            스톤헨지          1
# 4883500              보석            목걸이       매트로시티 목걸이          3
# 4883501           이미용가전         헤어드라이어          헤어드라이기          1
# 4883502            메이크업  블러셔/쉐이딩/하이라이터      바비브라운 크러쉬드          1
# 4883503            메이크업  블러셔/쉐이딩/하이라이터      바비브라운 크러쉬드          1
#
# [4883504 rows x 21 columns]

# %% [markdown]
# - Hit번호만 다르고 나머지 element의 내용이 같은 row가 여러 개가 있는 경우(중복 행) -> Hit번호가 가장 큰 row만 남긴다

# %% [markdown]
# # 2. 온라인 선호지수 개발

# %% [markdown]
# 1) 구매선호지수(client i, 상품군 j)
# - Product 데이터를 이용(실제 구매 데이터), 다른 item 대비 특정 상품군을 얼마나 구매하였는가  = 특정 상품군 구매 개수 / 각 client의 총 구매 개수
# - client i = 1~375839 (Product, Search1, Custom모두에 정보가 있는 Client)

# %%
Client_Used = Client_Behavior[['CLNT_ID']]
Client_Used = Client_Used.drop_duplicates(subset=None, keep='last', inplace=False)

# %%
print(len(Client_Used['CLNT_ID'].value_counts()))
# Out:
# 375839

# %%
Product_Used = pd.merge(Product, Client_Used, how = 'inner', on = 'CLNT_ID')

# %%
print(len(Product_Used['CLNT_ID'].value_counts()))
# Out:
# 375839
